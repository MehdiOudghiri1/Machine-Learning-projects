# %%
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Suppress TensorFlow warnings

import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
from tensorflow.keras import datasets, layers, models

# %%
(training_images,training_lables),(testing_images,testing_labels) = datasets.cifar10.load_data()
training_images, testing_images = training_images / 255, testing_images / 255

# %%
import matplotlib.pyplot as plt

class_names = ['Plane', 'Car', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# Adjusting the figure size and layout
plt.figure(figsize=(10, 10))

for i in range(16):
    plt.subplot(7 ,7, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(training_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[training_lables[i][0]], fontsize=12)  # Adjust the font size if necessary

# Adjust spacing between subplots
plt.tight_layout()
plt.show()

# %%
training_images = training_images[:20000]
training_lables = training_lables[:20000]
testing_images = testing_images[:4000]
testing_labels = testing_labels[:4000]

# %%
original_shape = training_images[0].shape
index = 0
same_format = True

for image in training_images:
    if original_shape != image.shape:
        print(f"There is a different format at index {index}")
        print(f"The shape is equal to {image.shape}")
        same_format = False
        break
    index += 1

if same_format:
    print("They all have the same format")
# Out:
# They all have the same format

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3,3), activation = 'relu', input_shape = training_images[0].shape))

# %%
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64, (3,3), activation='relu'))
model.add(layers.MaxPooling2D((2,2))
